# %%
import cv2
import numpy as np 
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import matplotlib.image as image
from PIL import Image, ImageOps
from numpy import asarray
import threading

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)#Color conversion BGR 2 RGB
    image.flags.writeable = False #Image is unwriteable
    results = model.process(image)#Make prediction
    image.flags.writeable = True#Image is now writeable
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)#color conversion RGB 2 BGR
    return image, results

# %%
def draw_styled_landmarks(image, results):
    #Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS,
                             mp_drawing.DrawingSpec(color=(80, 110, 10), thickness = 1, circle_radius =1),
                             mp_drawing.DrawingSpec(color=(80, 256, 121), thickness = 1, circle_radius =1)
                             )
    #Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80, 22, 10), thickness = 2, circle_radius =4),
                             mp_drawing.DrawingSpec(color=(80, 44, 121), thickness = 2, circle_radius =2)
                             )
    #Draw hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(121, 22, 76), thickness = 2, circle_radius =4),
                             mp_drawing.DrawingSpec(color=(121, 44, 250), thickness = 2, circle_radius =2)
                             )
    #Draw hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(245, 117, 66), thickness = 2, circle_radius =4),
                             mp_drawing.DrawingSpec(color=(245, 66, 230), thickness = 2, circle_radius =2)
                             )

# %%
def extract_keypoints(results):
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if \
        results.face_landmarks else np.zeros(468*3)
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if \
        results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if \
        results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if \
        results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
mp_holistic = mp.solutions.holistic #Holistic model
mp_drawing = mp.solutions.drawing_utils #Drawing utilities

# %% [markdown]
# # Khi nào đổi động tác thì chạy lại cái ô này và ô tạo folder bên dưới

# %%
count = 0 #Vị trí hiện tại nằm trong khoảng 0-29 của frame của folder thứ folder_num
folder_num = 0 # Vị trí hiện tại nằm trong khoảng 0-29 của folder chứa các frame
dem = 0 #Ảnh thứ bao nhiêu trong folder _image
#Tên hành động, làm hành động nào thì sửa tên cái folderName này thành hành động đó
#Ví dụ làm hành động uống nước thì folderName = 'drinkWater'
folderName = 'wait' 
folderForImage = folderName + '_image'
folderForNpy = folderName
IMAGE_PATH = os.path.join('MP_Data_60FPS', folderForImage)
NPY_PATH = os.path.join('MP_Data_60FPS', folderForNpy)

# %% [markdown]
# # Tạo 2 folder để lưu dữ liệu: folder lưu ảnh để check và folder lưu dữ liệu dưới dạng nparray

# %%
os.makedirs(IMAGE_PATH)
for i in range(60):
    try:
        os.makedirs(os.path.join(NPY_PATH, str(i)))
    except Exception as exception:
        print(exception)
        pass

# %% [markdown]
# # KÉO XUỐNG DƯỚI CÓ CODE CHECK CAM TRƯỚC KHI QUAY THẬT ĐỂ SET GÓC CHO CHUẨN

# %%
numb_of_frame = 30
numb_of_sequence = 60

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    for sequence_num in range(numb_of_sequence):
        # NEW LOOP
        # Loop through actions
        # Loop through video length aka sequence length
        for frame_num in range(numb_of_frame):
            npy_path = os.path.join(NPY_PATH, str(sequence_num), str(frame_num))
            img_path = os.path.join(IMAGE_PATH, '%d.jpg' % dem)
            # Read feed
            ret, frame = cap.read()

            # Make detections
            image, results = mediapipe_detection(frame, holistic)
    #                 print(results)

            # Draw landmarks
            draw_styled_landmarks(image, results)
            # NEW Apply wait logic
            if frame_num == 0: 
                cv2.putText(image, 'PREPARE COLLECTION', (120,200), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(folderName, sequence_num), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
             # Show to screen
                cv2.imshow('OpenCV Feed', image)
                cv2.waitKey(2000)
            else: 
                cv2.putText(image, 'Collecting {} frames for {} Video Number {}'.format(frame_num, folderName, sequence_num), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
            # Show to screen
                cv2.imshow('OpenCV Feed', image)

            # NEW Export keypoints

            keypoints = extract_keypoints(results)
            print("Save data to ", npy_path)
            np.save(npy_path, keypoints)
            cv2.imwrite(img_path, image)
            dem += 1   
    #             cv2.imwrite(os.path.join("MP_Data", "%d.jpg" % count), cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    #             keypoints = extract_keypoints(results)
    #             npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
    #             np.save(npy_path, keypoints)

            # Break gracefully
            if cv2.waitKey(10) & 0xFF == ord('q'):
                    break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# Save data to  MP_Data_60FPS\wait\0\0
# Save data to  MP_Data_60FPS\wait\0\1
# Save data to  MP_Data_60FPS\wait\0\2
# Save data to  MP_Data_60FPS\wait\0\3
# Save data to  MP_Data_60FPS\wait\0\4
# Save data to  MP_Data_60FPS\wait\0\5
# Save data to  MP_Data_60FPS\wait\0\6
# Save data to  MP_Data_60FPS\wait\0\7
# Save data to  MP_Data_60FPS\wait\0\8
# Save data to  MP_Data_60FPS\wait\0\9
# Save data to  MP_Data_60FPS\wait\0\10
# Save data to  MP_Data_60FPS\wait\0\11
# Save data to  MP_Data_60FPS\wait\0\12
# Save data to  MP_Data_60FPS\wait\0\13
# Save data to  MP_Data_60FPS\wait\0\14
# Save data to  MP_Data_60FPS\wait\0\15
# Save data to  MP_Data_60FPS\wait\0\16
# Save data to  MP_Data_60FPS\wait\0\17
# Save data to  MP_Data_60FPS\wait\0\18
# Save data to  MP_Data_60FPS\wait\0\19
# Save data to  MP_Data_60FPS\wait\0\20
# Save data to  MP_Data_60FPS\wait\0\21
# Save data to  MP_Data_60FPS\wait\0\22
# Save data to  MP_Data_60FPS\wait\0\23
# Save data to  MP_Data_60FPS\wait\0\24
# Save data to  MP_Data_60FPS\wait\0\25
# Save data to  MP_Data_60FPS\wait\0\26
# Save data to  MP_Data_60FPS\wait\0\27
# Save data to  MP_Data_60FPS\wait\0\28
# Save data to  MP_Data_60FPS\wait\0\29
# Save data to  MP_Data_60FPS\wait\1\0
# Save data to  MP_Data_60FPS\wait\1\1
# Save data to  MP_Data_60FPS\wait\1\2
# Save data to  MP_Data_60FPS\wait\1\3
# Save data to  MP_Data_60FPS\wait\1\4
# Save data to  MP_Data_60FPS\wait\1\5
# Save data to  MP_Data_60FPS\wait\1\6
# Save data to  MP_Data_60FPS\wait\1\7
# Save data to  MP_Data_60FPS\wait\1\8
# Save data to  MP_Data_60FPS\wait\1\9
# Save data to  MP_Data_60FPS\wait\1\10
# Save data to  MP_Data_60FPS\wait\1\11
# Save data to  MP_Data_60FPS\wait\1\12
# Save data to  MP_Data_60FPS\wait\1\13
# Save data to  MP_Data_60FPS\wait\1\14
# Save data to  MP_Data_60FPS\wait\1\15
# Save data to  MP_Data_60FPS\wait\1\16
# Save data to  MP_Data_60FPS\wait\1\17
# Save data to  MP_Data_60FPS\wait\1\18
# Save data to  MP_Data_60FPS\wait\1\19
# Save data to  MP_Data_60FPS\wait\1\20
# Save data to  MP_Data_60FPS\wait\1\21
# Save data to  MP_Data_60FPS\wait\1\22
# Save data to  MP_Data_60FPS\wait\1\23
# Save data to  MP_Data_60FPS\wait\1\24
# Save data to  MP_Data_60FPS\wait\1\25
# Save data to  MP_Data_60FPS\wait\1\26
# Save data to  MP_Data_60FPS\wait\1\27
# Save data to  MP_Data_60FPS\wait\1\28
# Save data to  MP_Data_60FPS\wait\1\29
# Save data to  MP_Data_60FPS\wait\2\0
# Save data to  MP_Data_60FPS\wait\2\1
# Save data to  MP_Data_60FPS\wait\2\2
# Save data to  MP_Data_60FPS\wait\2\3
# Save data to  MP_Data_60FPS\wait\2\4
# Save data to  MP_Data_60FPS\wait\2\5
# Save data to  MP_Data_60FPS\wait\2\6
# Save data to  MP_Data_60FPS\wait\2\7
# Save data to  MP_Data_60FPS\wait\2\8
# Save data to  MP_Data_60FPS\wait\2\9
# Save data to  MP_Data_60FPS\wait\2\10
# Save data to  MP_Data_60FPS\wait\2\11
# Save data to  MP_Data_60FPS\wait\2\12
# Save data to  MP_Data_60FPS\wait\2\13
# Save data to  MP_Data_60FPS\wait\2\14
# Save data to  MP_Data_60FPS\wait\2\15
# Save data to  MP_Data_60FPS\wait\2\16
# Save data to  MP_Data_60FPS\wait\2\17
# Save data to  MP_Data_60FPS\wait\2\18
# Save data to  MP_Data_60FPS\wait\2\19
# Save data to  MP_Data_60FPS\wait\2\20
# Save data to  MP_Data_60FPS\wait\2\21
# Save data to  MP_Data_60FPS\wait\2\22
# Save data to  MP_Data_60FPS\wait\2\23
# Save data to  MP_Data_60FPS\wait\2\24
# Save data to  MP_Data_60FPS\wait\2\25
# Save data to  MP_Data_60FPS\wait\2\26
# Save data to  MP_Data_60FPS\wait\2\27
# Save data to  MP_Data_60FPS\wait\2\28
# Save data to  MP_Data_60FPS\wait\2\29
# Save data to  MP_Data_60FPS\wait\3\0
# Save data to  MP_Data_60FPS\wait\3\1
# Save data to  MP_Data_60FPS\wait\3\2
# Save data to  MP_Data_60FPS\wait\3\3
# Save data to  MP_Data_60FPS\wait\3\4
# Save data to  MP_Data_60FPS\wait\3\5
# Save data to  MP_Data_60FPS\wait\3\6
# Save data to  MP_Data_60FPS\wait\3\7
# Save data to  MP_Data_60FPS\wait\3\8
# Save data to  MP_Data_60FPS\wait\3\9
# Save data to  MP_Data_60FPS\wait\3\10
# Save data to  MP_Data_60FPS\wait\3\11
# Save data to  MP_Data_60FPS\wait\3\12
# Save data to  MP_Data_60FPS\wait\3\13
# Save data to  MP_Data_60FPS\wait\3\14
# Save data to  MP_Data_60FPS\wait\3\15
# Save data to  MP_Data_60FPS\wait\3\16
# Save data to  MP_Data_60FPS\wait\3\17
# Save data to  MP_Data_60FPS\wait\3\18
# Save data to  MP_Data_60FPS\wait\3\19
# Save data to  MP_Data_60FPS\wait\3\20
# Save data to  MP_Data_60FPS\wait\3\21
# Save data to  MP_Data_60FPS\wait\3\22
# Save data to  MP_Data_60FPS\wait\3\23
# Save data to  MP_Data_60FPS\wait\3\24
# Save data to  MP_Data_60FPS\wait\3\25
# Save data to  MP_Data_60FPS\wait\3\26
# Save data to  MP_Data_60FPS\wait\3\27
# Save data to  MP_Data_60FPS\wait\3\28
# Save data to  MP_Data_60FPS\wait\3\29
# Save data to  MP_Data_60FPS\wait\4\0
# Save data to  MP_Data_60FPS\wait\4\1
# Save data to  MP_Data_60FPS\wait\4\2
# Save data to  MP_Data_60FPS\wait\4\3
# Save data to  MP_Data_60FPS\wait\4\4
# Save data to  MP_Data_60FPS\wait\4\5
# Save data to  MP_Data_60FPS\wait\4\6
# Save data to  MP_Data_60FPS\wait\4\7
# Save data to  MP_Data_60FPS\wait\4\8
# Save data to  MP_Data_60FPS\wait\4\9
# Save data to  MP_Data_60FPS\wait\4\10
# Save data to  MP_Data_60FPS\wait\4\11
# Save data to  MP_Data_60FPS\wait\4\12
# Save data to  MP_Data_60FPS\wait\4\13
# Save data to  MP_Data_60FPS\wait\4\14
# Save data to  MP_Data_60FPS\wait\4\15
# Save data to  MP_Data_60FPS\wait\4\16
# Save data to  MP_Data_60FPS\wait\4\17
# Save data to  MP_Data_60FPS\wait\4\18
# Save data to  MP_Data_60FPS\wait\4\19
# Save data to  MP_Data_60FPS\wait\4\20
# Save data to  MP_Data_60FPS\wait\4\21
# Save data to  MP_Data_60FPS\wait\4\22
# Save data to  MP_Data_60FPS\wait\4\23
# Save data to  MP_Data_60FPS\wait\4\24
# Save data to  MP_Data_60FPS\wait\4\25
# Save data to  MP_Data_60FPS\wait\4\26
# Save data to  MP_Data_60FPS\wait\4\27
# Save data to  MP_Data_60FPS\wait\4\28
# Save data to  MP_Data_60FPS\wait\4\29
# Save data to  MP_Data_60FPS\wait\5\0
# Save data to  MP_Data_60FPS\wait\5\1
# Save data to  MP_Data_60FPS\wait\5\2
# Save data to  MP_Data_60FPS\wait\5\3
# Save data to  MP_Data_60FPS\wait\5\4
# Save data to  MP_Data_60FPS\wait\5\5
# Save data to  MP_Data_60FPS\wait\5\6
# Save data to  MP_Data_60FPS\wait\5\7
# Save data to  MP_Data_60FPS\wait\5\8
# Save data to  MP_Data_60FPS\wait\5\9
# Save data to  MP_Data_60FPS\wait\5\10
# Save data to  MP_Data_60FPS\wait\5\11
# Save data to  MP_Data_60FPS\wait\5\12
# Save data to  MP_Data_60FPS\wait\5\13
# Save data to  MP_Data_60FPS\wait\5\14
# Save data to  MP_Data_60FPS\wait\5\15
# Save data to  MP_Data_60FPS\wait\5\16
# Save data to  MP_Data_60FPS\wait\5\17
# Save data to  MP_Data_60FPS\wait\5\18
# Save data to  MP_Data_60FPS\wait\5\19
# Save data to  MP_Data_60FPS\wait\5\20
# Save data to  MP_Data_60FPS\wait\5\21
# Save data to  MP_Data_60FPS\wait\5\22
# Save data to  MP_Data_60FPS\wait\5\23
# Save data to  MP_Data_60FPS\wait\5\24
# Save data to  MP_Data_60FPS\wait\5\25
# Save data to  MP_Data_60FPS\wait\5\26
# Save data to  MP_Data_60FPS\wait\5\27
# Save data to  MP_Data_60FPS\wait\5\28
# Save data to  MP_Data_60FPS\wait\5\29
# Save data to  MP_Data_60FPS\wait\6\0
# Save data to  MP_Data_60FPS\wait\6\1
# Save data to  MP_Data_60FPS\wait\6\2
# Save data to  MP_Data_60FPS\wait\6\3
# Save data to  MP_Data_60FPS\wait\6\4
# Save data to  MP_Data_60FPS\wait\6\5
# Save data to  MP_Data_60FPS\wait\6\6
# Save data to  MP_Data_60FPS\wait\6\7
# Save data to  MP_Data_60FPS\wait\6\8
# Save data to  MP_Data_60FPS\wait\6\9
# Save data to  MP_Data_60FPS\wait\6\10
# Save data to  MP_Data_60FPS\wait\6\11
# Save data to  MP_Data_60FPS\wait\6\12
# Save data to  MP_Data_60FPS\wait\6\13
# Save data to  MP_Data_60FPS\wait\6\14
# Save data to  MP_Data_60FPS\wait\6\15
# Save data to  MP_Data_60FPS\wait\6\16
# Save data to  MP_Data_60FPS\wait\6\17
# Save data to  MP_Data_60FPS\wait\6\18
# Save data to  MP_Data_60FPS\wait\6\19
# Save data to  MP_Data_60FPS\wait\6\20
# Save data to  MP_Data_60FPS\wait\6\21
# Save data to  MP_Data_60FPS\wait\6\22
# Save data to  MP_Data_60FPS\wait\6\23
# Save data to  MP_Data_60FPS\wait\6\24
# Save data to  MP_Data_60FPS\wait\6\25
# Save data to  MP_Data_60FPS\wait\6\26
# Save data to  MP_Data_60FPS\wait\6\27
# Save data to  MP_Data_60FPS\wait\6\28
# Save data to  MP_Data_60FPS\wait\6\29
# Save data to  MP_Data_60FPS\wait\7\0
# Save data to  MP_Data_60FPS\wait\7\1
# Save data to  MP_Data_60FPS\wait\7\2
# Save data to  MP_Data_60FPS\wait\7\3
# Save data to  MP_Data_60FPS\wait\7\4
# Save data to  MP_Data_60FPS\wait\7\5
# Save data to  MP_Data_60FPS\wait\7\6
# Save data to  MP_Data_60FPS\wait\7\7
# Save data to  MP_Data_60FPS\wait\7\8
# Save data to  MP_Data_60FPS\wait\7\9
# Save data to  MP_Data_60FPS\wait\7\10
# Save data to  MP_Data_60FPS\wait\7\11
# Save data to  MP_Data_60FPS\wait\7\12
# Save data to  MP_Data_60FPS\wait\7\13
# Save data to  MP_Data_60FPS\wait\7\14
# Save data to  MP_Data_60FPS\wait\7\15
# Save data to  MP_Data_60FPS\wait\7\16
# Save data to  MP_Data_60FPS\wait\7\17
# Save data to  MP_Data_60FPS\wait\7\18
# Save data to  MP_Data_60FPS\wait\7\19
# Save data to  MP_Data_60FPS\wait\7\20
# Save data to  MP_Data_60FPS\wait\7\21
# Save data to  MP_Data_60FPS\wait\7\22
# Save data to  MP_Data_60FPS\wait\7\23
# Save data to  MP_Data_60FPS\wait\7\24
# Save data to  MP_Data_60FPS\wait\7\25
# Save data to  MP_Data_60FPS\wait\7\26
# Save data to  MP_Data_60FPS\wait\7\27
# Save data to  MP_Data_60FPS\wait\7\28
# Save data to  MP_Data_60FPS\wait\7\29
# Save data to  MP_Data_60FPS\wait\8\0
# Save data to  MP_Data_60FPS\wait\8\1
# Save data to  MP_Data_60FPS\wait\8\2
# Save data to  MP_Data_60FPS\wait\8\3
# Save data to  MP_Data_60FPS\wait\8\4
# Save data to  MP_Data_60FPS\wait\8\5
# Save data to  MP_Data_60FPS\wait\8\6
# Save data to  MP_Data_60FPS\wait\8\7
# Save data to  MP_Data_60FPS\wait\8\8
# Save data to  MP_Data_60FPS\wait\8\9
# Save data to  MP_Data_60FPS\wait\8\10
# Save data to  MP_Data_60FPS\wait\8\11
# Save data to  MP_Data_60FPS\wait\8\12
# Save data to  MP_Data_60FPS\wait\8\13
# Save data to  MP_Data_60FPS\wait\8\14
# Save data to  MP_Data_60FPS\wait\8\15
# Save data to  MP_Data_60FPS\wait\8\16
# Save data to  MP_Data_60FPS\wait\8\17
# Save data to  MP_Data_60FPS\wait\8\18
# Save data to  MP_Data_60FPS\wait\8\19
# Save data to  MP_Data_60FPS\wait\8\20
# Save data to  MP_Data_60FPS\wait\8\21
# Save data to  MP_Data_60FPS\wait\8\22
# Save data to  MP_Data_60FPS\wait\8\23
# Save data to  MP_Data_60FPS\wait\8\24
# Save data to  MP_Data_60FPS\wait\8\25
# Save data to  MP_Data_60FPS\wait\8\26
# Save data to  MP_Data_60FPS\wait\8\27
# Save data to  MP_Data_60FPS\wait\8\28
# Save data to  MP_Data_60FPS\wait\8\29
# Save data to  MP_Data_60FPS\wait\9\0
# Save data to  MP_Data_60FPS\wait\9\1
# Save data to  MP_Data_60FPS\wait\9\2
# Save data to  MP_Data_60FPS\wait\9\3
# Save data to  MP_Data_60FPS\wait\9\4
# Save data to  MP_Data_60FPS\wait\9\5
# Save data to  MP_Data_60FPS\wait\9\6
# Save data to  MP_Data_60FPS\wait\9\7
# Save data to  MP_Data_60FPS\wait\9\8
# Save data to  MP_Data_60FPS\wait\9\9
# Save data to  MP_Data_60FPS\wait\9\10
# Save data to  MP_Data_60FPS\wait\9\11
# Save data to  MP_Data_60FPS\wait\9\12
# Save data to  MP_Data_60FPS\wait\9\13
# Save data to  MP_Data_60FPS\wait\9\14
# Save data to  MP_Data_60FPS\wait\9\15
# Save data to  MP_Data_60FPS\wait\9\16
# Save data to  MP_Data_60FPS\wait\9\17
# Save data to  MP_Data_60FPS\wait\9\18
# Save data to  MP_Data_60FPS\wait\9\19
# Save data to  MP_Data_60FPS\wait\9\20
# Save data to  MP_Data_60FPS\wait\9\21
# Save data to  MP_Data_60FPS\wait\9\22
# Save data to  MP_Data_60FPS\wait\9\23
# Save data to  MP_Data_60FPS\wait\9\24
# Save data to  MP_Data_60FPS\wait\9\25
# Save data to  MP_Data_60FPS\wait\9\26
# Save data to  MP_Data_60FPS\wait\9\27
# Save data to  MP_Data_60FPS\wait\9\28
# Save data to  MP_Data_60FPS\wait\9\29
# Save data to  MP_Data_60FPS\wait\10\0
# Save data to  MP_Data_60FPS\wait\10\1
# Save data to  MP_Data_60FPS\wait\10\2
# Save data to  MP_Data_60FPS\wait\10\3
# Save data to  MP_Data_60FPS\wait\10\4
# Save data to  MP_Data_60FPS\wait\10\5
# Save data to  MP_Data_60FPS\wait\10\6
# Save data to  MP_Data_60FPS\wait\10\7
# Save data to  MP_Data_60FPS\wait\10\8
# Save data to  MP_Data_60FPS\wait\10\9
# Save data to  MP_Data_60FPS\wait\10\10
# Save data to  MP_Data_60FPS\wait\10\11
# Save data to  MP_Data_60FPS\wait\10\12
# Save data to  MP_Data_60FPS\wait\10\13
# Save data to  MP_Data_60FPS\wait\10\14
# Save data to  MP_Data_60FPS\wait\10\15
# Save data to  MP_Data_60FPS\wait\10\16
# Save data to  MP_Data_60FPS\wait\10\17
# Save data to  MP_Data_60FPS\wait\10\18
# Save data to  MP_Data_60FPS\wait\10\19
# Save data to  MP_Data_60FPS\wait\10\20
# Save data to  MP_Data_60FPS\wait\10\21
# Save data to  MP_Data_60FPS\wait\10\22
# Save data to  MP_Data_60FPS\wait\10\23
# Save data to  MP_Data_60FPS\wait\10\24
# Save data to  MP_Data_60FPS\wait\10\25
# Save data to  MP_Data_60FPS\wait\10\26
# Save data to  MP_Data_60FPS\wait\10\27
# Save data to  MP_Data_60FPS\wait\10\28
# Save data to  MP_Data_60FPS\wait\10\29
# Save data to  MP_Data_60FPS\wait\11\0
# Save data to  MP_Data_60FPS\wait\11\1
# Save data to  MP_Data_60FPS\wait\11\2
# Save data to  MP_Data_60FPS\wait\11\3
# Save data to  MP_Data_60FPS\wait\11\4
# Save data to  MP_Data_60FPS\wait\11\5
# Save data to  MP_Data_60FPS\wait\11\6
# Save data to  MP_Data_60FPS\wait\11\7
# Save data to  MP_Data_60FPS\wait\11\8
# Save data to  MP_Data_60FPS\wait\11\9
# Save data to  MP_Data_60FPS\wait\11\10
# Save data to  MP_Data_60FPS\wait\11\11
# Save data to  MP_Data_60FPS\wait\11\12
# Save data to  MP_Data_60FPS\wait\11\13
# Save data to  MP_Data_60FPS\wait\11\14
# Save data to  MP_Data_60FPS\wait\11\15
# Save data to  MP_Data_60FPS\wait\11\16
# Save data to  MP_Data_60FPS\wait\11\17
# Save data to  MP_Data_60FPS\wait\11\18
# Save data to  MP_Data_60FPS\wait\11\19
# Save data to  MP_Data_60FPS\wait\11\20
# Save data to  MP_Data_60FPS\wait\11\21
# Save data to  MP_Data_60FPS\wait\11\22
# Save data to  MP_Data_60FPS\wait\11\23
# Save data to  MP_Data_60FPS\wait\11\24
# Save data to  MP_Data_60FPS\wait\11\25
# Save data to  MP_Data_60FPS\wait\11\26
# Save data to  MP_Data_60FPS\wait\11\27
# Save data to  MP_Data_60FPS\wait\11\28
# Save data to  MP_Data_60FPS\wait\11\29
# Save data to  MP_Data_60FPS\wait\12\0
# Save data to  MP_Data_60FPS\wait\12\1
# Save data to  MP_Data_60FPS\wait\12\2
# Save data to  MP_Data_60FPS\wait\12\3
# Save data to  MP_Data_60FPS\wait\12\4
# Save data to  MP_Data_60FPS\wait\12\5
# Save data to  MP_Data_60FPS\wait\12\6
# Save data to  MP_Data_60FPS\wait\12\7
# Save data to  MP_Data_60FPS\wait\12\8
# Save data to  MP_Data_60FPS\wait\12\9
# Save data to  MP_Data_60FPS\wait\12\10
# Save data to  MP_Data_60FPS\wait\12\11
# Save data to  MP_Data_60FPS\wait\12\12
# Save data to  MP_Data_60FPS\wait\12\13
# Save data to  MP_Data_60FPS\wait\12\14
# Save data to  MP_Data_60FPS\wait\12\15
# Save data to  MP_Data_60FPS\wait\12\16
# Save data to  MP_Data_60FPS\wait\12\17
# Save data to  MP_Data_60FPS\wait\12\18
# Save data to  MP_Data_60FPS\wait\12\19
# Save data to  MP_Data_60FPS\wait\12\20
# Save data to  MP_Data_60FPS\wait\12\21
# Save data to  MP_Data_60FPS\wait\12\22
# Save data to  MP_Data_60FPS\wait\12\23
# Save data to  MP_Data_60FPS\wait\12\24
# Save data to  MP_Data_60FPS\wait\12\25
# Save data to  MP_Data_60FPS\wait\12\26
# Save data to  MP_Data_60FPS\wait\12\27
# Save data to  MP_Data_60FPS\wait\12\28
# Save data to  MP_Data_60FPS\wait\12\29
# Save data to  MP_Data_60FPS\wait\13\0
# Save data to  MP_Data_60FPS\wait\13\1
# Save data to  MP_Data_60FPS\wait\13\2
# Save data to  MP_Data_60FPS\wait\13\3
# Save data to  MP_Data_60FPS\wait\13\4
# Save data to  MP_Data_60FPS\wait\13\5
# Save data to  MP_Data_60FPS\wait\13\6
# Save data to  MP_Data_60FPS\wait\13\7
# Save data to  MP_Data_60FPS\wait\13\8
# Save data to  MP_Data_60FPS\wait\13\9
# Save data to  MP_Data_60FPS\wait\13\10
# Save data to  MP_Data_60FPS\wait\13\11
# Save data to  MP_Data_60FPS\wait\13\12
# Save data to  MP_Data_60FPS\wait\13\13
# Save data to  MP_Data_60FPS\wait\13\14
# Save data to  MP_Data_60FPS\wait\13\15
# Save data to  MP_Data_60FPS\wait\13\16
# Save data to  MP_Data_60FPS\wait\13\17
# Save data to  MP_Data_60FPS\wait\13\18
# Save data to  MP_Data_60FPS\wait\13\19
# Save data to  MP_Data_60FPS\wait\13\20
# Save data to  MP_Data_60FPS\wait\13\21
# Save data to  MP_Data_60FPS\wait\13\22
# Save data to  MP_Data_60FPS\wait\13\23
# Save data to  MP_Data_60FPS\wait\13\24
# Save data to  MP_Data_60FPS\wait\13\25
# Save data to  MP_Data_60FPS\wait\13\26
# Save data to  MP_Data_60FPS\wait\13\27
# Save data to  MP_Data_60FPS\wait\13\28
# Save data to  MP_Data_60FPS\wait\13\29
# Save data to  MP_Data_60FPS\wait\14\0
# Save data to  MP_Data_60FPS\wait\14\1
# Save data to  MP_Data_60FPS\wait\14\2
# Save data to  MP_Data_60FPS\wait\14\3
# Save data to  MP_Data_60FPS\wait\14\4
# Save data to  MP_Data_60FPS\wait\14\5
# Save data to  MP_Data_60FPS\wait\14\6
# Save data to  MP_Data_60FPS\wait\14\7
# Save data to  MP_Data_60FPS\wait\14\8
# Save data to  MP_Data_60FPS\wait\14\9
# Save data to  MP_Data_60FPS\wait\14\10
# Save data to  MP_Data_60FPS\wait\14\11
# Save data to  MP_Data_60FPS\wait\14\12
# Save data to  MP_Data_60FPS\wait\14\13
# Save data to  MP_Data_60FPS\wait\14\14
# Save data to  MP_Data_60FPS\wait\14\15
# Save data to  MP_Data_60FPS\wait\14\16
# Save data to  MP_Data_60FPS\wait\14\17
# Save data to  MP_Data_60FPS\wait\14\18
# Save data to  MP_Data_60FPS\wait\14\19
# Save data to  MP_Data_60FPS\wait\14\20
# Save data to  MP_Data_60FPS\wait\14\21
# Save data to  MP_Data_60FPS\wait\14\22
# Save data to  MP_Data_60FPS\wait\14\23
# Save data to  MP_Data_60FPS\wait\14\24
# Save data to  MP_Data_60FPS\wait\14\25
# Save data to  MP_Data_60FPS\wait\14\26
# Save data to  MP_Data_60FPS\wait\14\27
# Save data to  MP_Data_60FPS\wait\14\28
# Save data to  MP_Data_60FPS\wait\14\29
# Save data to  MP_Data_60FPS\wait\15\0
# Save data to  MP_Data_60FPS\wait\15\1
# Save data to  MP_Data_60FPS\wait\15\2
# Save data to  MP_Data_60FPS\wait\15\3
# Save data to  MP_Data_60FPS\wait\15\4
# Save data to  MP_Data_60FPS\wait\15\5
# Save data to  MP_Data_60FPS\wait\15\6
# Save data to  MP_Data_60FPS\wait\15\7
# Save data to  MP_Data_60FPS\wait\15\8
# Save data to  MP_Data_60FPS\wait\15\9
# Save data to  MP_Data_60FPS\wait\15\10
# Save data to  MP_Data_60FPS\wait\15\11
# Save data to  MP_Data_60FPS\wait\15\12
# Save data to  MP_Data_60FPS\wait\15\13
# Save data to  MP_Data_60FPS\wait\15\14
# Save data to  MP_Data_60FPS\wait\15\15
# Save data to  MP_Data_60FPS\wait\15\16
# Save data to  MP_Data_60FPS\wait\15\17
# Save data to  MP_Data_60FPS\wait\15\18
# Save data to  MP_Data_60FPS\wait\15\19
# Save data to  MP_Data_60FPS\wait\15\20
# Save data to  MP_Data_60FPS\wait\15\21
# Save data to  MP_Data_60FPS\wait\15\22
# Save data to  MP_Data_60FPS\wait\15\23
# Save data to  MP_Data_60FPS\wait\15\24
# Save data to  MP_Data_60FPS\wait\15\25
# Save data to  MP_Data_60FPS\wait\15\26
# Save data to  MP_Data_60FPS\wait\15\27
# Save data to  MP_Data_60FPS\wait\15\28
# Save data to  MP_Data_60FPS\wait\15\29
# Save data to  MP_Data_60FPS\wait\16\0
# Save data to  MP_Data_60FPS\wait\16\1
# Save data to  MP_Data_60FPS\wait\16\2
# Save data to  MP_Data_60FPS\wait\16\3
# Save data to  MP_Data_60FPS\wait\16\4
# Save data to  MP_Data_60FPS\wait\16\5
# Save data to  MP_Data_60FPS\wait\16\6
# Save data to  MP_Data_60FPS\wait\16\7
# Save data to  MP_Data_60FPS\wait\16\8
# Save data to  MP_Data_60FPS\wait\16\9
# Save data to  MP_Data_60FPS\wait\16\10
# Save data to  MP_Data_60FPS\wait\16\11
# Save data to  MP_Data_60FPS\wait\16\12
# Save data to  MP_Data_60FPS\wait\16\13
# Save data to  MP_Data_60FPS\wait\16\14
# Save data to  MP_Data_60FPS\wait\16\15
# Save data to  MP_Data_60FPS\wait\16\16
# Save data to  MP_Data_60FPS\wait\16\17
# Save data to  MP_Data_60FPS\wait\16\18
# Save data to  MP_Data_60FPS\wait\16\19
# Save data to  MP_Data_60FPS\wait\16\20
# Save data to  MP_Data_60FPS\wait\16\21
# Save data to  MP_Data_60FPS\wait\16\22
# Save data to  MP_Data_60FPS\wait\16\23
# Save data to  MP_Data_60FPS\wait\16\24
# Save data to  MP_Data_60FPS\wait\16\25
# Save data to  MP_Data_60FPS\wait\16\26
# Save data to  MP_Data_60FPS\wait\16\27
# Save data to  MP_Data_60FPS\wait\16\28
# Save data to  MP_Data_60FPS\wait\16\29
# Save data to  MP_Data_60FPS\wait\17\0
# Save data to  MP_Data_60FPS\wait\17\1
# Save data to  MP_Data_60FPS\wait\17\2
# Save data to  MP_Data_60FPS\wait\17\3
# Save data to  MP_Data_60FPS\wait\17\4
# Save data to  MP_Data_60FPS\wait\17\5
# Save data to  MP_Data_60FPS\wait\17\6
# Save data to  MP_Data_60FPS\wait\17\7
# Save data to  MP_Data_60FPS\wait\17\8
# Save data to  MP_Data_60FPS\wait\17\9
# Save data to  MP_Data_60FPS\wait\17\10
# Save data to  MP_Data_60FPS\wait\17\11
# Save data to  MP_Data_60FPS\wait\17\12
# Save data to  MP_Data_60FPS\wait\17\13
# Save data to  MP_Data_60FPS\wait\17\14
# Save data to  MP_Data_60FPS\wait\17\15
# Save data to  MP_Data_60FPS\wait\17\16
# Save data to  MP_Data_60FPS\wait\17\17
# Save data to  MP_Data_60FPS\wait\17\18
# Save data to  MP_Data_60FPS\wait\17\19
# Save data to  MP_Data_60FPS\wait\17\20
# Save data to  MP_Data_60FPS\wait\17\21
# Save data to  MP_Data_60FPS\wait\17\22
# Save data to  MP_Data_60FPS\wait\17\23
# Save data to  MP_Data_60FPS\wait\17\24
# Save data to  MP_Data_60FPS\wait\17\25
# Save data to  MP_Data_60FPS\wait\17\26
# Save data to  MP_Data_60FPS\wait\17\27
# Save data to  MP_Data_60FPS\wait\17\28
# Save data to  MP_Data_60FPS\wait\17\29
# Save data to  MP_Data_60FPS\wait\18\0
# Save data to  MP_Data_60FPS\wait\18\1
# Save data to  MP_Data_60FPS\wait\18\2
# Save data to  MP_Data_60FPS\wait\18\3
# Save data to  MP_Data_60FPS\wait\18\4
# Save data to  MP_Data_60FPS\wait\18\5
# Save data to  MP_Data_60FPS\wait\18\6
# Save data to  MP_Data_60FPS\wait\18\7
# Save data to  MP_Data_60FPS\wait\18\8
# Save data to  MP_Data_60FPS\wait\18\9
# Save data to  MP_Data_60FPS\wait\18\10
# Save data to  MP_Data_60FPS\wait\18\11
# Save data to  MP_Data_60FPS\wait\18\12
# Save data to  MP_Data_60FPS\wait\18\13
# Save data to  MP_Data_60FPS\wait\18\14
# Save data to  MP_Data_60FPS\wait\18\15
# Save data to  MP_Data_60FPS\wait\18\16
# Save data to  MP_Data_60FPS\wait\18\17
# Save data to  MP_Data_60FPS\wait\18\18
# Save data to  MP_Data_60FPS\wait\18\19
# Save data to  MP_Data_60FPS\wait\18\20
# Save data to  MP_Data_60FPS\wait\18\21
# Save data to  MP_Data_60FPS\wait\18\22
# Save data to  MP_Data_60FPS\wait\18\23
# Save data to  MP_Data_60FPS\wait\18\24
# Save data to  MP_Data_60FPS\wait\18\25
# Save data to  MP_Data_60FPS\wait\18\26
# Save data to  MP_Data_60FPS\wait\18\27
# Save data to  MP_Data_60FPS\wait\18\28
# Save data to  MP_Data_60FPS\wait\18\29
# Save data to  MP_Data_60FPS\wait\19\0
# Save data to  MP_Data_60FPS\wait\19\1
# Save data to  MP_Data_60FPS\wait\19\2
# Save data to  MP_Data_60FPS\wait\19\3
# Save data to  MP_Data_60FPS\wait\19\4
# Save data to  MP_Data_60FPS\wait\19\5
# Save data to  MP_Data_60FPS\wait\19\6
# Save data to  MP_Data_60FPS\wait\19\7
# Save data to  MP_Data_60FPS\wait\19\8
# Save data to  MP_Data_60FPS\wait\19\9
# Save data to  MP_Data_60FPS\wait\19\10
# Save data to  MP_Data_60FPS\wait\19\11
# Save data to  MP_Data_60FPS\wait\19\12
# Save data to  MP_Data_60FPS\wait\19\13
# Save data to  MP_Data_60FPS\wait\19\14
# Save data to  MP_Data_60FPS\wait\19\15
# Save data to  MP_Data_60FPS\wait\19\16
# Save data to  MP_Data_60FPS\wait\19\17
# Save data to  MP_Data_60FPS\wait\19\18
# Save data to  MP_Data_60FPS\wait\19\19
# Save data to  MP_Data_60FPS\wait\19\20
# Save data to  MP_Data_60FPS\wait\19\21
# Save data to  MP_Data_60FPS\wait\19\22
# Save data to  MP_Data_60FPS\wait\19\23
# Save data to  MP_Data_60FPS\wait\19\24
# Save data to  MP_Data_60FPS\wait\19\25
# Save data to  MP_Data_60FPS\wait\19\26
# Save data to  MP_Data_60FPS\wait\19\27
# Save data to  MP_Data_60FPS\wait\19\28
# Save data to  MP_Data_60FPS\wait\19\29
# Save data to  MP_Data_60FPS\wait\20\0
# Save data to  MP_Data_60FPS\wait\20\1
# Save data to  MP_Data_60FPS\wait\20\2
# Save data to  MP_Data_60FPS\wait\20\3
# Save data to  MP_Data_60FPS\wait\20\4
# Save data to  MP_Data_60FPS\wait\20\5
# Save data to  MP_Data_60FPS\wait\20\6
# Save data to  MP_Data_60FPS\wait\20\7
# Save data to  MP_Data_60FPS\wait\20\8
# Save data to  MP_Data_60FPS\wait\20\9
# Save data to  MP_Data_60FPS\wait\20\10
# Save data to  MP_Data_60FPS\wait\20\11
# Save data to  MP_Data_60FPS\wait\20\12
# Save data to  MP_Data_60FPS\wait\20\13
# Save data to  MP_Data_60FPS\wait\20\14
# Save data to  MP_Data_60FPS\wait\20\15
# Save data to  MP_Data_60FPS\wait\20\16
# Save data to  MP_Data_60FPS\wait\20\17
# Save data to  MP_Data_60FPS\wait\20\18
# Save data to  MP_Data_60FPS\wait\20\19
# Save data to  MP_Data_60FPS\wait\20\20
# Save data to  MP_Data_60FPS\wait\20\21
# Save data to  MP_Data_60FPS\wait\20\22
# Save data to  MP_Data_60FPS\wait\20\23
# Save data to  MP_Data_60FPS\wait\20\24
# Save data to  MP_Data_60FPS\wait\20\25
# Save data to  MP_Data_60FPS\wait\20\26
# Save data to  MP_Data_60FPS\wait\20\27
# Save data to  MP_Data_60FPS\wait\20\28
# Save data to  MP_Data_60FPS\wait\20\29
# Save data to  MP_Data_60FPS\wait\21\0
# Save data to  MP_Data_60FPS\wait\21\1
# Save data to  MP_Data_60FPS\wait\21\2
# Save data to  MP_Data_60FPS\wait\21\3
# Save data to  MP_Data_60FPS\wait\21\4
# Save data to  MP_Data_60FPS\wait\21\5
# Save data to  MP_Data_60FPS\wait\21\6
# Save data to  MP_Data_60FPS\wait\21\7
# Save data to  MP_Data_60FPS\wait\21\8
# Save data to  MP_Data_60FPS\wait\21\9
# Save data to  MP_Data_60FPS\wait\21\10
# Save data to  MP_Data_60FPS\wait\21\11
# Save data to  MP_Data_60FPS\wait\21\12
# Save data to  MP_Data_60FPS\wait\21\13
# Save data to  MP_Data_60FPS\wait\21\14
# Save data to  MP_Data_60FPS\wait\21\15
# Save data to  MP_Data_60FPS\wait\21\16
# Save data to  MP_Data_60FPS\wait\21\17
# Save data to  MP_Data_60FPS\wait\21\18
# Save data to  MP_Data_60FPS\wait\21\19
# Save data to  MP_Data_60FPS\wait\21\20
# Save data to  MP_Data_60FPS\wait\21\21
# Save data to  MP_Data_60FPS\wait\21\22
# Save data to  MP_Data_60FPS\wait\21\23
# Save data to  MP_Data_60FPS\wait\21\24
# Save data to  MP_Data_60FPS\wait\21\25
# Save data to  MP_Data_60FPS\wait\21\26
# Save data to  MP_Data_60FPS\wait\21\27
# Save data to  MP_Data_60FPS\wait\21\28
# Save data to  MP_Data_60FPS\wait\21\29
# Save data to  MP_Data_60FPS\wait\22\0
# Save data to  MP_Data_60FPS\wait\22\1
# Save data to  MP_Data_60FPS\wait\22\2
# Save data to  MP_Data_60FPS\wait\22\3
# Save data to  MP_Data_60FPS\wait\22\4
# Save data to  MP_Data_60FPS\wait\22\5
# Save data to  MP_Data_60FPS\wait\22\6
# Save data to  MP_Data_60FPS\wait\22\7
# Save data to  MP_Data_60FPS\wait\22\8
# Save data to  MP_Data_60FPS\wait\22\9
# Save data to  MP_Data_60FPS\wait\22\10
# Save data to  MP_Data_60FPS\wait\22\11
# Save data to  MP_Data_60FPS\wait\22\12
# Save data to  MP_Data_60FPS\wait\22\13
# Save data to  MP_Data_60FPS\wait\22\14
# Save data to  MP_Data_60FPS\wait\22\15
# Save data to  MP_Data_60FPS\wait\22\16
# Save data to  MP_Data_60FPS\wait\22\17
# Save data to  MP_Data_60FPS\wait\22\18
# Save data to  MP_Data_60FPS\wait\22\19
# Save data to  MP_Data_60FPS\wait\22\20
# Save data to  MP_Data_60FPS\wait\22\21
# Save data to  MP_Data_60FPS\wait\22\22
# Save data to  MP_Data_60FPS\wait\22\23
# Save data to  MP_Data_60FPS\wait\22\24
# Save data to  MP_Data_60FPS\wait\22\25
# Save data to  MP_Data_60FPS\wait\22\26
# Save data to  MP_Data_60FPS\wait\22\27
# Save data to  MP_Data_60FPS\wait\22\28
# Save data to  MP_Data_60FPS\wait\22\29
# Save data to  MP_Data_60FPS\wait\23\0
# Save data to  MP_Data_60FPS\wait\23\1
# Save data to  MP_Data_60FPS\wait\23\2
# Save data to  MP_Data_60FPS\wait\23\3
# Save data to  MP_Data_60FPS\wait\23\4
# Save data to  MP_Data_60FPS\wait\23\5
# Save data to  MP_Data_60FPS\wait\23\6
# Save data to  MP_Data_60FPS\wait\23\7
# Save data to  MP_Data_60FPS\wait\23\8
# Save data to  MP_Data_60FPS\wait\23\9
# Save data to  MP_Data_60FPS\wait\23\10
# Save data to  MP_Data_60FPS\wait\23\11
# Save data to  MP_Data_60FPS\wait\23\12
# Save data to  MP_Data_60FPS\wait\23\13
# Save data to  MP_Data_60FPS\wait\23\14
# Save data to  MP_Data_60FPS\wait\23\15
# Save data to  MP_Data_60FPS\wait\23\16
# Save data to  MP_Data_60FPS\wait\23\17
# Save data to  MP_Data_60FPS\wait\23\18
# Save data to  MP_Data_60FPS\wait\23\19
# Save data to  MP_Data_60FPS\wait\23\20
# Save data to  MP_Data_60FPS\wait\23\21
# Save data to  MP_Data_60FPS\wait\23\22
# Save data to  MP_Data_60FPS\wait\23\23
# Save data to  MP_Data_60FPS\wait\23\24
# Save data to  MP_Data_60FPS\wait\23\25
# Save data to  MP_Data_60FPS\wait\23\26
# Save data to  MP_Data_60FPS\wait\23\27
# Save data to  MP_Data_60FPS\wait\23\28
# Save data to  MP_Data_60FPS\wait\23\29
# Save data to  MP_Data_60FPS\wait\24\0
# Save data to  MP_Data_60FPS\wait\24\1
# Save data to  MP_Data_60FPS\wait\24\2
# Save data to  MP_Data_60FPS\wait\24\3
# Save data to  MP_Data_60FPS\wait\24\4
# Save data to  MP_Data_60FPS\wait\24\5
# Save data to  MP_Data_60FPS\wait\24\6
# Save data to  MP_Data_60FPS\wait\24\7
# Save data to  MP_Data_60FPS\wait\24\8
# Save data to  MP_Data_60FPS\wait\24\9
# Save data to  MP_Data_60FPS\wait\24\10
# Save data to  MP_Data_60FPS\wait\24\11
# Save data to  MP_Data_60FPS\wait\24\12
# Save data to  MP_Data_60FPS\wait\24\13
# Save data to  MP_Data_60FPS\wait\24\14
# Save data to  MP_Data_60FPS\wait\24\15
# Save data to  MP_Data_60FPS\wait\24\16
# Save data to  MP_Data_60FPS\wait\24\17
# Save data to  MP_Data_60FPS\wait\24\18
# Save data to  MP_Data_60FPS\wait\24\19
# Save data to  MP_Data_60FPS\wait\24\20
# Save data to  MP_Data_60FPS\wait\24\21
# Save data to  MP_Data_60FPS\wait\24\22
# Save data to  MP_Data_60FPS\wait\24\23
# Save data to  MP_Data_60FPS\wait\24\24
# Save data to  MP_Data_60FPS\wait\24\25
# Save data to  MP_Data_60FPS\wait\24\26
# Save data to  MP_Data_60FPS\wait\24\27
# Save data to  MP_Data_60FPS\wait\24\28
# Save data to  MP_Data_60FPS\wait\24\29
# Save data to  MP_Data_60FPS\wait\25\0
# Save data to  MP_Data_60FPS\wait\25\1
# Save data to  MP_Data_60FPS\wait\25\2
# Save data to  MP_Data_60FPS\wait\25\3
# Save data to  MP_Data_60FPS\wait\25\4
# Save data to  MP_Data_60FPS\wait\25\5
# Save data to  MP_Data_60FPS\wait\25\6
# Save data to  MP_Data_60FPS\wait\25\7
# Save data to  MP_Data_60FPS\wait\25\8
# Save data to  MP_Data_60FPS\wait\25\9
# Save data to  MP_Data_60FPS\wait\25\10
# Save data to  MP_Data_60FPS\wait\25\11
# Save data to  MP_Data_60FPS\wait\25\12
# Save data to  MP_Data_60FPS\wait\25\13
# Save data to  MP_Data_60FPS\wait\25\14
# Save data to  MP_Data_60FPS\wait\25\15
# Save data to  MP_Data_60FPS\wait\25\16
# Save data to  MP_Data_60FPS\wait\25\17
# Save data to  MP_Data_60FPS\wait\25\18
# Save data to  MP_Data_60FPS\wait\25\19
# Save data to  MP_Data_60FPS\wait\25\20
# Save data to  MP_Data_60FPS\wait\25\21
# Save data to  MP_Data_60FPS\wait\25\22
# Save data to  MP_Data_60FPS\wait\25\23
# Save data to  MP_Data_60FPS\wait\25\24
# Save data to  MP_Data_60FPS\wait\25\25
# Save data to  MP_Data_60FPS\wait\25\26
# Save data to  MP_Data_60FPS\wait\25\27
# Save data to  MP_Data_60FPS\wait\25\28
# Save data to  MP_Data_60FPS\wait\25\29
# Save data to  MP_Data_60FPS\wait\26\0
# Save data to  MP_Data_60FPS\wait\26\1
# Save data to  MP_Data_60FPS\wait\26\2
# Save data to  MP_Data_60FPS\wait\26\3
# Save data to  MP_Data_60FPS\wait\26\4
# Save data to  MP_Data_60FPS\wait\26\5
# Save data to  MP_Data_60FPS\wait\26\6
# Save data to  MP_Data_60FPS\wait\26\7
# Save data to  MP_Data_60FPS\wait\26\8
# Save data to  MP_Data_60FPS\wait\26\9
# Save data to  MP_Data_60FPS\wait\26\10
# Save data to  MP_Data_60FPS\wait\26\11
# Save data to  MP_Data_60FPS\wait\26\12
# Save data to  MP_Data_60FPS\wait\26\13
# Save data to  MP_Data_60FPS\wait\26\14
# Save data to  MP_Data_60FPS\wait\26\15
# Save data to  MP_Data_60FPS\wait\26\16
# Save data to  MP_Data_60FPS\wait\26\17
# Save data to  MP_Data_60FPS\wait\26\18
# Save data to  MP_Data_60FPS\wait\26\19
# Save data to  MP_Data_60FPS\wait\26\20
# Save data to  MP_Data_60FPS\wait\26\21
# Save data to  MP_Data_60FPS\wait\26\22
# Save data to  MP_Data_60FPS\wait\26\23
# Save data to  MP_Data_60FPS\wait\26\24
# Save data to  MP_Data_60FPS\wait\26\25
# Save data to  MP_Data_60FPS\wait\26\26
# Save data to  MP_Data_60FPS\wait\26\27
# Save data to  MP_Data_60FPS\wait\26\28
# Save data to  MP_Data_60FPS\wait\26\29
# Save data to  MP_Data_60FPS\wait\27\0
# Save data to  MP_Data_60FPS\wait\27\1
# Save data to  MP_Data_60FPS\wait\27\2
# Save data to  MP_Data_60FPS\wait\27\3
# Save data to  MP_Data_60FPS\wait\27\4
# Save data to  MP_Data_60FPS\wait\27\5
# Save data to  MP_Data_60FPS\wait\27\6
# Save data to  MP_Data_60FPS\wait\27\7
# Save data to  MP_Data_60FPS\wait\27\8
# Save data to  MP_Data_60FPS\wait\27\9
# Save data to  MP_Data_60FPS\wait\27\10
# Save data to  MP_Data_60FPS\wait\27\11
# Save data to  MP_Data_60FPS\wait\27\12
# Save data to  MP_Data_60FPS\wait\27\13
# Save data to  MP_Data_60FPS\wait\27\14
# Save data to  MP_Data_60FPS\wait\27\15
# Save data to  MP_Data_60FPS\wait\27\16
# Save data to  MP_Data_60FPS\wait\27\17
# Save data to  MP_Data_60FPS\wait\27\18
# Save data to  MP_Data_60FPS\wait\27\19
# Save data to  MP_Data_60FPS\wait\27\20
# Save data to  MP_Data_60FPS\wait\27\21
# Save data to  MP_Data_60FPS\wait\27\22
# Save data to  MP_Data_60FPS\wait\27\23
# Save data to  MP_Data_60FPS\wait\27\24
# Save data to  MP_Data_60FPS\wait\27\25
# Save data to  MP_Data_60FPS\wait\27\26
# Save data to  MP_Data_60FPS\wait\27\27
# Save data to  MP_Data_60FPS\wait\27\28
# Save data to  MP_Data_60FPS\wait\27\29
# Save data to  MP_Data_60FPS\wait\28\0
# Save data to  MP_Data_60FPS\wait\28\1
# Save data to  MP_Data_60FPS\wait\28\2
# Save data to  MP_Data_60FPS\wait\28\3
# Save data to  MP_Data_60FPS\wait\28\4
# Save data to  MP_Data_60FPS\wait\28\5
# Save data to  MP_Data_60FPS\wait\28\6
# Save data to  MP_Data_60FPS\wait\28\7
# Save data to  MP_Data_60FPS\wait\28\8
# Save data to  MP_Data_60FPS\wait\28\9
# Save data to  MP_Data_60FPS\wait\28\10
# Save data to  MP_Data_60FPS\wait\28\11
# Save data to  MP_Data_60FPS\wait\28\12
# Save data to  MP_Data_60FPS\wait\28\13
# Save data to  MP_Data_60FPS\wait\28\14
# Save data to  MP_Data_60FPS\wait\28\15
# Save data to  MP_Data_60FPS\wait\28\16
# Save data to  MP_Data_60FPS\wait\28\17
# Save data to  MP_Data_60FPS\wait\28\18
# Save data to  MP_Data_60FPS\wait\28\19
# Save data to  MP_Data_60FPS\wait\28\20
# Save data to  MP_Data_60FPS\wait\28\21
# Save data to  MP_Data_60FPS\wait\28\22
# Save data to  MP_Data_60FPS\wait\28\23
# Save data to  MP_Data_60FPS\wait\28\24
# Save data to  MP_Data_60FPS\wait\28\25
# Save data to  MP_Data_60FPS\wait\28\26
# Save data to  MP_Data_60FPS\wait\28\27
# Save data to  MP_Data_60FPS\wait\28\28
# Save data to  MP_Data_60FPS\wait\28\29
# Save data to  MP_Data_60FPS\wait\29\0
# Save data to  MP_Data_60FPS\wait\29\1
# Save data to  MP_Data_60FPS\wait\29\2
# Save data to  MP_Data_60FPS\wait\29\3
# Save data to  MP_Data_60FPS\wait\29\4
# Save data to  MP_Data_60FPS\wait\29\5
# Save data to  MP_Data_60FPS\wait\29\6
# Save data to  MP_Data_60FPS\wait\29\7
# Save data to  MP_Data_60FPS\wait\29\8
# Save data to  MP_Data_60FPS\wait\29\9
# Save data to  MP_Data_60FPS\wait\29\10
# Save data to  MP_Data_60FPS\wait\29\11
# Save data to  MP_Data_60FPS\wait\29\12
# Save data to  MP_Data_60FPS\wait\29\13
# Save data to  MP_Data_60FPS\wait\29\14
# Save data to  MP_Data_60FPS\wait\29\15
# Save data to  MP_Data_60FPS\wait\29\16
# Save data to  MP_Data_60FPS\wait\29\17
# Save data to  MP_Data_60FPS\wait\29\18
# Save data to  MP_Data_60FPS\wait\29\19
# Save data to  MP_Data_60FPS\wait\29\20
# Save data to  MP_Data_60FPS\wait\29\21
# Save data to  MP_Data_60FPS\wait\29\22
# Save data to  MP_Data_60FPS\wait\29\23
# Save data to  MP_Data_60FPS\wait\29\24
# Save data to  MP_Data_60FPS\wait\29\25
# Save data to  MP_Data_60FPS\wait\29\26
# Save data to  MP_Data_60FPS\wait\29\27
# Save data to  MP_Data_60FPS\wait\29\28
# Save data to  MP_Data_60FPS\wait\29\29
# Save data to  MP_Data_60FPS\wait\30\0
# Save data to  MP_Data_60FPS\wait\30\1
# Save data to  MP_Data_60FPS\wait\30\2
# Save data to  MP_Data_60FPS\wait\30\3
# Save data to  MP_Data_60FPS\wait\30\4
# Save data to  MP_Data_60FPS\wait\30\5
# Save data to  MP_Data_60FPS\wait\30\6
# Save data to  MP_Data_60FPS\wait\30\7
# Save data to  MP_Data_60FPS\wait\30\8
# Save data to  MP_Data_60FPS\wait\30\9
# Save data to  MP_Data_60FPS\wait\30\10
# Save data to  MP_Data_60FPS\wait\30\11
# Save data to  MP_Data_60FPS\wait\30\12
# Save data to  MP_Data_60FPS\wait\30\13
# Save data to  MP_Data_60FPS\wait\30\14
# Save data to  MP_Data_60FPS\wait\30\15
# Save data to  MP_Data_60FPS\wait\30\16
# Save data to  MP_Data_60FPS\wait\30\17
# Save data to  MP_Data_60FPS\wait\30\18
# Save data to  MP_Data_60FPS\wait\30\19
# Save data to  MP_Data_60FPS\wait\30\20
# Save data to  MP_Data_60FPS\wait\30\21
# Save data to  MP_Data_60FPS\wait\30\22
# Save data to  MP_Data_60FPS\wait\30\23
# Save data to  MP_Data_60FPS\wait\30\24
# Save data to  MP_Data_60FPS\wait\30\25
# Save data to  MP_Data_60FPS\wait\30\26
# Save data to  MP_Data_60FPS\wait\30\27
# Save data to  MP_Data_60FPS\wait\30\28
# Save data to  MP_Data_60FPS\wait\30\29
# Save data to  MP_Data_60FPS\wait\31\0
# Save data to  MP_Data_60FPS\wait\31\1
# Save data to  MP_Data_60FPS\wait\31\2
# Save data to  MP_Data_60FPS\wait\31\3
# Save data to  MP_Data_60FPS\wait\31\4
# Save data to  MP_Data_60FPS\wait\31\5
# Save data to  MP_Data_60FPS\wait\31\6
# Save data to  MP_Data_60FPS\wait\31\7
# Save data to  MP_Data_60FPS\wait\31\8
# Save data to  MP_Data_60FPS\wait\31\9
# Save data to  MP_Data_60FPS\wait\31\10
# Save data to  MP_Data_60FPS\wait\31\11
# Save data to  MP_Data_60FPS\wait\31\12
# Save data to  MP_Data_60FPS\wait\31\13
# Save data to  MP_Data_60FPS\wait\31\14
# Save data to  MP_Data_60FPS\wait\31\15
# Save data to  MP_Data_60FPS\wait\31\16
# Save data to  MP_Data_60FPS\wait\31\17
# Save data to  MP_Data_60FPS\wait\31\18
# Save data to  MP_Data_60FPS\wait\31\19
# Save data to  MP_Data_60FPS\wait\31\20
# Save data to  MP_Data_60FPS\wait\31\21
# Save data to  MP_Data_60FPS\wait\31\22
# Save data to  MP_Data_60FPS\wait\31\23
# Save data to  MP_Data_60FPS\wait\31\24
# Save data to  MP_Data_60FPS\wait\31\25
# Save data to  MP_Data_60FPS\wait\31\26
# Save data to  MP_Data_60FPS\wait\31\27
# Save data to  MP_Data_60FPS\wait\31\28
# Save data to  MP_Data_60FPS\wait\31\29
# Save data to  MP_Data_60FPS\wait\32\0
# Save data to  MP_Data_60FPS\wait\32\1
# Save data to  MP_Data_60FPS\wait\32\2
# Save data to  MP_Data_60FPS\wait\32\3
# Save data to  MP_Data_60FPS\wait\32\4
# Save data to  MP_Data_60FPS\wait\32\5
# Save data to  MP_Data_60FPS\wait\32\6
# Save data to  MP_Data_60FPS\wait\32\7
# Save data to  MP_Data_60FPS\wait\32\8
# Save data to  MP_Data_60FPS\wait\32\9
# Save data to  MP_Data_60FPS\wait\32\10
# Save data to  MP_Data_60FPS\wait\32\11
# Save data to  MP_Data_60FPS\wait\32\12
# Save data to  MP_Data_60FPS\wait\32\13
# Save data to  MP_Data_60FPS\wait\32\14
# Save data to  MP_Data_60FPS\wait\32\15
# Save data to  MP_Data_60FPS\wait\32\16
# Save data to  MP_Data_60FPS\wait\32\17
# Save data to  MP_Data_60FPS\wait\32\18
# Save data to  MP_Data_60FPS\wait\32\19
# Save data to  MP_Data_60FPS\wait\32\20
# Save data to  MP_Data_60FPS\wait\32\21
# Save data to  MP_Data_60FPS\wait\32\22
# Save data to  MP_Data_60FPS\wait\32\23
# Save data to  MP_Data_60FPS\wait\32\24
# Save data to  MP_Data_60FPS\wait\32\25
# Save data to  MP_Data_60FPS\wait\32\26
# Save data to  MP_Data_60FPS\wait\32\27
# Save data to  MP_Data_60FPS\wait\32\28
# Save data to  MP_Data_60FPS\wait\32\29
# Save data to  MP_Data_60FPS\wait\33\0
# Save data to  MP_Data_60FPS\wait\33\1
# Save data to  MP_Data_60FPS\wait\33\2
# Save data to  MP_Data_60FPS\wait\33\3
# Save data to  MP_Data_60FPS\wait\33\4
# Save data to  MP_Data_60FPS\wait\33\5
# Save data to  MP_Data_60FPS\wait\33\6
# Save data to  MP_Data_60FPS\wait\33\7
# Save data to  MP_Data_60FPS\wait\33\8
# Save data to  MP_Data_60FPS\wait\33\9
# Save data to  MP_Data_60FPS\wait\33\10
# Save data to  MP_Data_60FPS\wait\33\11
# Save data to  MP_Data_60FPS\wait\33\12
# Save data to  MP_Data_60FPS\wait\33\13
# Save data to  MP_Data_60FPS\wait\33\14
# Save data to  MP_Data_60FPS\wait\33\15
# Save data to  MP_Data_60FPS\wait\33\16
# Save data to  MP_Data_60FPS\wait\33\17
# Save data to  MP_Data_60FPS\wait\33\18
# Save data to  MP_Data_60FPS\wait\33\19
# Save data to  MP_Data_60FPS\wait\33\20
# Save data to  MP_Data_60FPS\wait\33\21
# Save data to  MP_Data_60FPS\wait\33\22
# Save data to  MP_Data_60FPS\wait\33\23
# Save data to  MP_Data_60FPS\wait\33\24
# Save data to  MP_Data_60FPS\wait\33\25
# Save data to  MP_Data_60FPS\wait\33\26
# Save data to  MP_Data_60FPS\wait\33\27
# Save data to  MP_Data_60FPS\wait\33\28
# Save data to  MP_Data_60FPS\wait\33\29
# Save data to  MP_Data_60FPS\wait\34\0
# Save data to  MP_Data_60FPS\wait\34\1
# Save data to  MP_Data_60FPS\wait\34\2
# Save data to  MP_Data_60FPS\wait\34\3
# Save data to  MP_Data_60FPS\wait\34\4
# Save data to  MP_Data_60FPS\wait\34\5
# Save data to  MP_Data_60FPS\wait\34\6
# Save data to  MP_Data_60FPS\wait\34\7
# Save data to  MP_Data_60FPS\wait\34\8
# Save data to  MP_Data_60FPS\wait\34\9
# Save data to  MP_Data_60FPS\wait\34\10
# Save data to  MP_Data_60FPS\wait\34\11
# Save data to  MP_Data_60FPS\wait\34\12
# Save data to  MP_Data_60FPS\wait\34\13
# Save data to  MP_Data_60FPS\wait\34\14
# Save data to  MP_Data_60FPS\wait\34\15
# Save data to  MP_Data_60FPS\wait\34\16
# Save data to  MP_Data_60FPS\wait\34\17
# Save data to  MP_Data_60FPS\wait\34\18
# Save data to  MP_Data_60FPS\wait\34\19
# Save data to  MP_Data_60FPS\wait\34\20
# Save data to  MP_Data_60FPS\wait\34\21
# Save data to  MP_Data_60FPS\wait\34\22
# Save data to  MP_Data_60FPS\wait\34\23
# Save data to  MP_Data_60FPS\wait\34\24
# Save data to  MP_Data_60FPS\wait\34\25
# Save data to  MP_Data_60FPS\wait\34\26
# Save data to  MP_Data_60FPS\wait\34\27
# Save data to  MP_Data_60FPS\wait\34\28
# Save data to  MP_Data_60FPS\wait\34\29
# Save data to  MP_Data_60FPS\wait\35\0
# Save data to  MP_Data_60FPS\wait\35\1
# Save data to  MP_Data_60FPS\wait\35\2
# Save data to  MP_Data_60FPS\wait\35\3
# Save data to  MP_Data_60FPS\wait\35\4
# Save data to  MP_Data_60FPS\wait\35\5
# Save data to  MP_Data_60FPS\wait\35\6
# Save data to  MP_Data_60FPS\wait\35\7
# Save data to  MP_Data_60FPS\wait\35\8
# Save data to  MP_Data_60FPS\wait\35\9
# Save data to  MP_Data_60FPS\wait\35\10
# Save data to  MP_Data_60FPS\wait\35\11
# Save data to  MP_Data_60FPS\wait\35\12
# Save data to  MP_Data_60FPS\wait\35\13
# Save data to  MP_Data_60FPS\wait\35\14
# Save data to  MP_Data_60FPS\wait\35\15
# Save data to  MP_Data_60FPS\wait\35\16
# Save data to  MP_Data_60FPS\wait\35\17
# Save data to  MP_Data_60FPS\wait\35\18
# Save data to  MP_Data_60FPS\wait\35\19
# Save data to  MP_Data_60FPS\wait\35\20
# Save data to  MP_Data_60FPS\wait\35\21
# Save data to  MP_Data_60FPS\wait\35\22
# Save data to  MP_Data_60FPS\wait\35\23
# Save data to  MP_Data_60FPS\wait\35\24
# Save data to  MP_Data_60FPS\wait\35\25
# Save data to  MP_Data_60FPS\wait\35\26
# Save data to  MP_Data_60FPS\wait\35\27
# Save data to  MP_Data_60FPS\wait\35\28
# Save data to  MP_Data_60FPS\wait\35\29
# Save data to  MP_Data_60FPS\wait\36\0
# Save data to  MP_Data_60FPS\wait\36\1
# Save data to  MP_Data_60FPS\wait\36\2
# Save data to  MP_Data_60FPS\wait\36\3
# Save data to  MP_Data_60FPS\wait\36\4
# Save data to  MP_Data_60FPS\wait\36\5
# Save data to  MP_Data_60FPS\wait\36\6
# Save data to  MP_Data_60FPS\wait\36\7
# Save data to  MP_Data_60FPS\wait\36\8
# Save data to  MP_Data_60FPS\wait\36\9
# Save data to  MP_Data_60FPS\wait\36\10
# Save data to  MP_Data_60FPS\wait\36\11
# Save data to  MP_Data_60FPS\wait\36\12
# Save data to  MP_Data_60FPS\wait\36\13
# Save data to  MP_Data_60FPS\wait\36\14
# Save data to  MP_Data_60FPS\wait\36\15
# Save data to  MP_Data_60FPS\wait\36\16
# Save data to  MP_Data_60FPS\wait\36\17
# Save data to  MP_Data_60FPS\wait\36\18
# Save data to  MP_Data_60FPS\wait\36\19
# Save data to  MP_Data_60FPS\wait\36\20
# Save data to  MP_Data_60FPS\wait\36\21
# Save data to  MP_Data_60FPS\wait\36\22
# Save data to  MP_Data_60FPS\wait\36\23
# Save data to  MP_Data_60FPS\wait\36\24
# Save data to  MP_Data_60FPS\wait\36\25
# Save data to  MP_Data_60FPS\wait\36\26
# Save data to  MP_Data_60FPS\wait\36\27
# Save data to  MP_Data_60FPS\wait\36\28
# Save data to  MP_Data_60FPS\wait\36\29
# Save data to  MP_Data_60FPS\wait\37\0
# Save data to  MP_Data_60FPS\wait\37\1
# Save data to  MP_Data_60FPS\wait\37\2
# Save data to  MP_Data_60FPS\wait\37\3
# Save data to  MP_Data_60FPS\wait\37\4
# Save data to  MP_Data_60FPS\wait\37\5
# Save data to  MP_Data_60FPS\wait\37\6
# Save data to  MP_Data_60FPS\wait\37\7
# Save data to  MP_Data_60FPS\wait\37\8
# Save data to  MP_Data_60FPS\wait\37\9
# Save data to  MP_Data_60FPS\wait\37\10
# Save data to  MP_Data_60FPS\wait\37\11
# Save data to  MP_Data_60FPS\wait\37\12
# Save data to  MP_Data_60FPS\wait\37\13
# Save data to  MP_Data_60FPS\wait\37\14
# Save data to  MP_Data_60FPS\wait\37\15
# Save data to  MP_Data_60FPS\wait\37\16
# Save data to  MP_Data_60FPS\wait\37\17
# Save data to  MP_Data_60FPS\wait\37\18
# Save data to  MP_Data_60FPS\wait\37\19
# Save data to  MP_Data_60FPS\wait\37\20
# Save data to  MP_Data_60FPS\wait\37\21
# Save data to  MP_Data_60FPS\wait\37\22
# Save data to  MP_Data_60FPS\wait\37\23
# Save data to  MP_Data_60FPS\wait\37\24
# Save data to  MP_Data_60FPS\wait\37\25
# Save data to  MP_Data_60FPS\wait\37\26
# Save data to  MP_Data_60FPS\wait\37\27
# Save data to  MP_Data_60FPS\wait\37\28
# Save data to  MP_Data_60FPS\wait\37\29
# Save data to  MP_Data_60FPS\wait\38\0
# Save data to  MP_Data_60FPS\wait\38\1
# Save data to  MP_Data_60FPS\wait\38\2
# Save data to  MP_Data_60FPS\wait\38\3
# Save data to  MP_Data_60FPS\wait\38\4
# Save data to  MP_Data_60FPS\wait\38\5
# Save data to  MP_Data_60FPS\wait\38\6
# Save data to  MP_Data_60FPS\wait\38\7
# Save data to  MP_Data_60FPS\wait\38\8
# Save data to  MP_Data_60FPS\wait\38\9
# Save data to  MP_Data_60FPS\wait\38\10
# Save data to  MP_Data_60FPS\wait\38\11
# Save data to  MP_Data_60FPS\wait\38\12
# Save data to  MP_Data_60FPS\wait\38\13
# Save data to  MP_Data_60FPS\wait\38\14
# Save data to  MP_Data_60FPS\wait\38\15
# Save data to  MP_Data_60FPS\wait\38\16
# Save data to  MP_Data_60FPS\wait\38\17
# Save data to  MP_Data_60FPS\wait\38\18
# Save data to  MP_Data_60FPS\wait\38\19
# Save data to  MP_Data_60FPS\wait\38\20
# Save data to  MP_Data_60FPS\wait\38\21
# Save data to  MP_Data_60FPS\wait\38\22
# Save data to  MP_Data_60FPS\wait\38\23
# Save data to  MP_Data_60FPS\wait\38\24
# Save data to  MP_Data_60FPS\wait\38\25
# Save data to  MP_Data_60FPS\wait\38\26
# Save data to  MP_Data_60FPS\wait\38\27
# Save data to  MP_Data_60FPS\wait\38\28
# Save data to  MP_Data_60FPS\wait\38\29
# Save data to  MP_Data_60FPS\wait\39\0
# Save data to  MP_Data_60FPS\wait\39\1
# Save data to  MP_Data_60FPS\wait\39\2
# Save data to  MP_Data_60FPS\wait\39\3
# Save data to  MP_Data_60FPS\wait\39\4
# Save data to  MP_Data_60FPS\wait\39\5
# Save data to  MP_Data_60FPS\wait\39\6
# Save data to  MP_Data_60FPS\wait\39\7
# Save data to  MP_Data_60FPS\wait\39\8
# Save data to  MP_Data_60FPS\wait\39\9
# Save data to  MP_Data_60FPS\wait\39\10
# Save data to  MP_Data_60FPS\wait\39\11
# Save data to  MP_Data_60FPS\wait\39\12
# Save data to  MP_Data_60FPS\wait\39\13
# Save data to  MP_Data_60FPS\wait\39\14
# Save data to  MP_Data_60FPS\wait\39\15
# Save data to  MP_Data_60FPS\wait\39\16
# Save data to  MP_Data_60FPS\wait\39\17
# Save data to  MP_Data_60FPS\wait\39\18
# Save data to  MP_Data_60FPS\wait\39\19
# Save data to  MP_Data_60FPS\wait\39\20
# Save data to  MP_Data_60FPS\wait\39\21
# Save data to  MP_Data_60FPS\wait\39\22
# Save data to  MP_Data_60FPS\wait\39\23
# Save data to  MP_Data_60FPS\wait\39\24
# Save data to  MP_Data_60FPS\wait\39\25
# Save data to  MP_Data_60FPS\wait\39\26
# Save data to  MP_Data_60FPS\wait\39\27
# Save data to  MP_Data_60FPS\wait\39\28
# Save data to  MP_Data_60FPS\wait\39\29
# Save data to  MP_Data_60FPS\wait\40\0
# Save data to  MP_Data_60FPS\wait\40\1
# Save data to  MP_Data_60FPS\wait\40\2
# Save data to  MP_Data_60FPS\wait\40\3
# Save data to  MP_Data_60FPS\wait\40\4
# Save data to  MP_Data_60FPS\wait\40\5
# Save data to  MP_Data_60FPS\wait\40\6
# Save data to  MP_Data_60FPS\wait\40\7
# Save data to  MP_Data_60FPS\wait\40\8
# Save data to  MP_Data_60FPS\wait\40\9
# Save data to  MP_Data_60FPS\wait\40\10
# Save data to  MP_Data_60FPS\wait\40\11
# Save data to  MP_Data_60FPS\wait\40\12
# Save data to  MP_Data_60FPS\wait\40\13
# Save data to  MP_Data_60FPS\wait\40\14
# Save data to  MP_Data_60FPS\wait\40\15
# Save data to  MP_Data_60FPS\wait\40\16
# Save data to  MP_Data_60FPS\wait\40\17
# Save data to  MP_Data_60FPS\wait\40\18
# Save data to  MP_Data_60FPS\wait\40\19
# Save data to  MP_Data_60FPS\wait\40\20
# Save data to  MP_Data_60FPS\wait\40\21
# Save data to  MP_Data_60FPS\wait\40\22
# Save data to  MP_Data_60FPS\wait\40\23
# Save data to  MP_Data_60FPS\wait\40\24
# Save data to  MP_Data_60FPS\wait\40\25
# Save data to  MP_Data_60FPS\wait\40\26
# Save data to  MP_Data_60FPS\wait\40\27
# Save data to  MP_Data_60FPS\wait\40\28
# Save data to  MP_Data_60FPS\wait\40\29
# Save data to  MP_Data_60FPS\wait\41\0
# Save data to  MP_Data_60FPS\wait\41\1
# Save data to  MP_Data_60FPS\wait\41\2
# Save data to  MP_Data_60FPS\wait\41\3
# Save data to  MP_Data_60FPS\wait\41\4
# Save data to  MP_Data_60FPS\wait\41\5
# Save data to  MP_Data_60FPS\wait\41\6
# Save data to  MP_Data_60FPS\wait\41\7
# Save data to  MP_Data_60FPS\wait\41\8
# Save data to  MP_Data_60FPS\wait\41\9
# Save data to  MP_Data_60FPS\wait\41\10
# Save data to  MP_Data_60FPS\wait\41\11
# Save data to  MP_Data_60FPS\wait\41\12
# Save data to  MP_Data_60FPS\wait\41\13
# Save data to  MP_Data_60FPS\wait\41\14
# Save data to  MP_Data_60FPS\wait\41\15
# Save data to  MP_Data_60FPS\wait\41\16
# Save data to  MP_Data_60FPS\wait\41\17
# Save data to  MP_Data_60FPS\wait\41\18
# ...
# Save data to  MP_Data_60FPS\wait\46\7
# Save data to  MP_Data_60FPS\wait\46\8
# Save data to  MP_Data_60FPS\wait\46\9
# Save data to  MP_Data_60FPS\wait\46\10
# Save data to  MP_Data_60FPS\wait\46\11
# Save data to  MP_Data_60FPS\wait\46\12
# Save data to  MP_Data_60FPS\wait\46\13
# Save data to  MP_Data_60FPS\wait\46\14
# Save data to  MP_Data_60FPS\wait\46\15
# Save data to  MP_Data_60FPS\wait\46\16
# Save data to  MP_Data_60FPS\wait\46\17
# Save data to  MP_Data_60FPS\wait\46\18
# Save data to  MP_Data_60FPS\wait\46\19
# Save data to  MP_Data_60FPS\wait\46\20
# Save data to  MP_Data_60FPS\wait\46\21
# Save data to  MP_Data_60FPS\wait\46\22
# Save data to  MP_Data_60FPS\wait\46\23
# Save data to  MP_Data_60FPS\wait\46\24
# Save data to  MP_Data_60FPS\wait\46\25
# Save data to  MP_Data_60FPS\wait\46\26
# Save data to  MP_Data_60FPS\wait\46\27
# Save data to  MP_Data_60FPS\wait\46\28
# Save data to  MP_Data_60FPS\wait\46\29
# Save data to  MP_Data_60FPS\wait\47\0
# Save data to  MP_Data_60FPS\wait\47\1
# Save data to  MP_Data_60FPS\wait\47\2
# Save data to  MP_Data_60FPS\wait\47\3
# Save data to  MP_Data_60FPS\wait\47\4
# Save data to  MP_Data_60FPS\wait\47\5
# Save data to  MP_Data_60FPS\wait\47\6
# Save data to  MP_Data_60FPS\wait\47\7
# Save data to  MP_Data_60FPS\wait\47\8
# Save data to  MP_Data_60FPS\wait\47\9
# Save data to  MP_Data_60FPS\wait\47\10
# Save data to  MP_Data_60FPS\wait\47\11
# Save data to  MP_Data_60FPS\wait\47\12
# Save data to  MP_Data_60FPS\wait\47\13
# Save data to  MP_Data_60FPS\wait\47\14
# Save data to  MP_Data_60FPS\wait\47\15
# Save data to  MP_Data_60FPS\wait\47\16
# Save data to  MP_Data_60FPS\wait\47\17
# Save data to  MP_Data_60FPS\wait\47\18
# Save data to  MP_Data_60FPS\wait\47\19
# Save data to  MP_Data_60FPS\wait\47\20
# Save data to  MP_Data_60FPS\wait\47\21
# Save data to  MP_Data_60FPS\wait\47\22
# Save data to  MP_Data_60FPS\wait\47\23
# Save data to  MP_Data_60FPS\wait\47\24
# Save data to  MP_Data_60FPS\wait\47\25
# Save data to  MP_Data_60FPS\wait\47\26
# Save data to  MP_Data_60FPS\wait\47\27
# Save data to  MP_Data_60FPS\wait\47\28
# Save data to  MP_Data_60FPS\wait\47\29
# Save data to  MP_Data_60FPS\wait\48\0
# Save data to  MP_Data_60FPS\wait\48\1
# Save data to  MP_Data_60FPS\wait\48\2
# Save data to  MP_Data_60FPS\wait\48\3
# Save data to  MP_Data_60FPS\wait\48\4
# Save data to  MP_Data_60FPS\wait\48\5
# Save data to  MP_Data_60FPS\wait\48\6
# Save data to  MP_Data_60FPS\wait\48\7
# Save data to  MP_Data_60FPS\wait\48\8
# Save data to  MP_Data_60FPS\wait\48\9
# Save data to  MP_Data_60FPS\wait\48\10
# Save data to  MP_Data_60FPS\wait\48\11
# Save data to  MP_Data_60FPS\wait\48\12
# Save data to  MP_Data_60FPS\wait\48\13
# Save data to  MP_Data_60FPS\wait\48\14
# Save data to  MP_Data_60FPS\wait\48\15
# Save data to  MP_Data_60FPS\wait\48\16
# Save data to  MP_Data_60FPS\wait\48\17
# Save data to  MP_Data_60FPS\wait\48\18
# Save data to  MP_Data_60FPS\wait\48\19
# Save data to  MP_Data_60FPS\wait\48\20
# Save data to  MP_Data_60FPS\wait\48\21
# Save data to  MP_Data_60FPS\wait\48\22
# Save data to  MP_Data_60FPS\wait\48\23
# Save data to  MP_Data_60FPS\wait\48\24
# Save data to  MP_Data_60FPS\wait\48\25
# Save data to  MP_Data_60FPS\wait\48\26
# Save data to  MP_Data_60FPS\wait\48\27
# Save data to  MP_Data_60FPS\wait\48\28
# Save data to  MP_Data_60FPS\wait\48\29
# Save data to  MP_Data_60FPS\wait\49\0
# Save data to  MP_Data_60FPS\wait\49\1
# Save data to  MP_Data_60FPS\wait\49\2
# Save data to  MP_Data_60FPS\wait\49\3
# Save data to  MP_Data_60FPS\wait\49\4
# Save data to  MP_Data_60FPS\wait\49\5
# Save data to  MP_Data_60FPS\wait\49\6
# Save data to  MP_Data_60FPS\wait\49\7
# Save data to  MP_Data_60FPS\wait\49\8
# Save data to  MP_Data_60FPS\wait\49\9
# Save data to  MP_Data_60FPS\wait\49\10
# Save data to  MP_Data_60FPS\wait\49\11
# Save data to  MP_Data_60FPS\wait\49\12
# Save data to  MP_Data_60FPS\wait\49\13
# Save data to  MP_Data_60FPS\wait\49\14
# Save data to  MP_Data_60FPS\wait\49\15
# Save data to  MP_Data_60FPS\wait\49\16
# Save data to  MP_Data_60FPS\wait\49\17
# Save data to  MP_Data_60FPS\wait\49\18
# Save data to  MP_Data_60FPS\wait\49\19
# Save data to  MP_Data_60FPS\wait\49\20
# Save data to  MP_Data_60FPS\wait\49\21
# Save data to  MP_Data_60FPS\wait\49\22
# Save data to  MP_Data_60FPS\wait\49\23
# Save data to  MP_Data_60FPS\wait\49\24
# Save data to  MP_Data_60FPS\wait\49\25
# Save data to  MP_Data_60FPS\wait\49\26
# Save data to  MP_Data_60FPS\wait\49\27
# Save data to  MP_Data_60FPS\wait\49\28
# Save data to  MP_Data_60FPS\wait\49\29
# Save data to  MP_Data_60FPS\wait\50\0
# Save data to  MP_Data_60FPS\wait\50\1
# Save data to  MP_Data_60FPS\wait\50\2
# Save data to  MP_Data_60FPS\wait\50\3
# Save data to  MP_Data_60FPS\wait\50\4
# Save data to  MP_Data_60FPS\wait\50\5
# Save data to  MP_Data_60FPS\wait\50\6
# Save data to  MP_Data_60FPS\wait\50\7
# Save data to  MP_Data_60FPS\wait\50\8
# Save data to  MP_Data_60FPS\wait\50\9
# Save data to  MP_Data_60FPS\wait\50\10
# Save data to  MP_Data_60FPS\wait\50\11
# Save data to  MP_Data_60FPS\wait\50\12
# Save data to  MP_Data_60FPS\wait\50\13
# Save data to  MP_Data_60FPS\wait\50\14
# Save data to  MP_Data_60FPS\wait\50\15
# Save data to  MP_Data_60FPS\wait\50\16
# Save data to  MP_Data_60FPS\wait\50\17
# Save data to  MP_Data_60FPS\wait\50\18
# Save data to  MP_Data_60FPS\wait\50\19
# Save data to  MP_Data_60FPS\wait\50\20
# Save data to  MP_Data_60FPS\wait\50\21
# Save data to  MP_Data_60FPS\wait\50\22
# Save data to  MP_Data_60FPS\wait\50\23
# Save data to  MP_Data_60FPS\wait\50\24
# Save data to  MP_Data_60FPS\wait\50\25
# Save data to  MP_Data_60FPS\wait\50\26
# Save data to  MP_Data_60FPS\wait\50\27
# Save data to  MP_Data_60FPS\wait\50\28
# Save data to  MP_Data_60FPS\wait\50\29
# Save data to  MP_Data_60FPS\wait\51\0
# Save data to  MP_Data_60FPS\wait\51\1
# Save data to  MP_Data_60FPS\wait\51\2
# Save data to  MP_Data_60FPS\wait\51\3
# Save data to  MP_Data_60FPS\wait\51\4
# Save data to  MP_Data_60FPS\wait\51\5
# Save data to  MP_Data_60FPS\wait\51\6
# Save data to  MP_Data_60FPS\wait\51\7
# Save data to  MP_Data_60FPS\wait\51\8
# Save data to  MP_Data_60FPS\wait\51\9
# Save data to  MP_Data_60FPS\wait\51\10
# Save data to  MP_Data_60FPS\wait\51\11
# Save data to  MP_Data_60FPS\wait\51\12
# Save data to  MP_Data_60FPS\wait\51\13
# Save data to  MP_Data_60FPS\wait\51\14
# Save data to  MP_Data_60FPS\wait\51\15
# Save data to  MP_Data_60FPS\wait\51\16
# Save data to  MP_Data_60FPS\wait\51\17
# Save data to  MP_Data_60FPS\wait\51\18
# Save data to  MP_Data_60FPS\wait\51\19
# Save data to  MP_Data_60FPS\wait\51\20
# Save data to  MP_Data_60FPS\wait\51\21
# Save data to  MP_Data_60FPS\wait\51\22
# Save data to  MP_Data_60FPS\wait\51\23
# Save data to  MP_Data_60FPS\wait\51\24
# Save data to  MP_Data_60FPS\wait\51\25
# Save data to  MP_Data_60FPS\wait\51\26
# Save data to  MP_Data_60FPS\wait\51\27
# Save data to  MP_Data_60FPS\wait\51\28
# Save data to  MP_Data_60FPS\wait\51\29
# Save data to  MP_Data_60FPS\wait\52\0
# Save data to  MP_Data_60FPS\wait\52\1
# Save data to  MP_Data_60FPS\wait\52\2
# Save data to  MP_Data_60FPS\wait\52\3
# Save data to  MP_Data_60FPS\wait\52\4
# Save data to  MP_Data_60FPS\wait\52\5
# Save data to  MP_Data_60FPS\wait\52\6
# Save data to  MP_Data_60FPS\wait\52\7
# Save data to  MP_Data_60FPS\wait\52\8
# Save data to  MP_Data_60FPS\wait\52\9
# Save data to  MP_Data_60FPS\wait\52\10
# Save data to  MP_Data_60FPS\wait\52\11
# Save data to  MP_Data_60FPS\wait\52\12
# Save data to  MP_Data_60FPS\wait\52\13
# Save data to  MP_Data_60FPS\wait\52\14
# Save data to  MP_Data_60FPS\wait\52\15
# Save data to  MP_Data_60FPS\wait\52\16
# Save data to  MP_Data_60FPS\wait\52\17
# Save data to  MP_Data_60FPS\wait\52\18
# Save data to  MP_Data_60FPS\wait\52\19
# Save data to  MP_Data_60FPS\wait\52\20
# Save data to  MP_Data_60FPS\wait\52\21
# Save data to  MP_Data_60FPS\wait\52\22
# Save data to  MP_Data_60FPS\wait\52\23
# Save data to  MP_Data_60FPS\wait\52\24
# Save data to  MP_Data_60FPS\wait\52\25
# Save data to  MP_Data_60FPS\wait\52\26
# Save data to  MP_Data_60FPS\wait\52\27
# Save data to  MP_Data_60FPS\wait\52\28
# Save data to  MP_Data_60FPS\wait\52\29
# Save data to  MP_Data_60FPS\wait\53\0
# Save data to  MP_Data_60FPS\wait\53\1
# Save data to  MP_Data_60FPS\wait\53\2
# Save data to  MP_Data_60FPS\wait\53\3
# Save data to  MP_Data_60FPS\wait\53\4
# Save data to  MP_Data_60FPS\wait\53\5
# Save data to  MP_Data_60FPS\wait\53\6
# Save data to  MP_Data_60FPS\wait\53\7
# Save data to  MP_Data_60FPS\wait\53\8
# Save data to  MP_Data_60FPS\wait\53\9
# Save data to  MP_Data_60FPS\wait\53\10
# Save data to  MP_Data_60FPS\wait\53\11
# Save data to  MP_Data_60FPS\wait\53\12
# Save data to  MP_Data_60FPS\wait\53\13
# Save data to  MP_Data_60FPS\wait\53\14
# Save data to  MP_Data_60FPS\wait\53\15
# Save data to  MP_Data_60FPS\wait\53\16
# Save data to  MP_Data_60FPS\wait\53\17
# Save data to  MP_Data_60FPS\wait\53\18
# Save data to  MP_Data_60FPS\wait\53\19
# Save data to  MP_Data_60FPS\wait\53\20
# Save data to  MP_Data_60FPS\wait\53\21
# Save data to  MP_Data_60FPS\wait\53\22
# Save data to  MP_Data_60FPS\wait\53\23
# Save data to  MP_Data_60FPS\wait\53\24
# Save data to  MP_Data_60FPS\wait\53\25
# Save data to  MP_Data_60FPS\wait\53\26
# Save data to  MP_Data_60FPS\wait\53\27
# Save data to  MP_Data_60FPS\wait\53\28
# Save data to  MP_Data_60FPS\wait\53\29
# Save data to  MP_Data_60FPS\wait\54\0
# Save data to  MP_Data_60FPS\wait\54\1
# Save data to  MP_Data_60FPS\wait\54\2
# Save data to  MP_Data_60FPS\wait\54\3
# Save data to  MP_Data_60FPS\wait\54\4
# Save data to  MP_Data_60FPS\wait\54\5
# Save data to  MP_Data_60FPS\wait\54\6
# Save data to  MP_Data_60FPS\wait\54\7
# Save data to  MP_Data_60FPS\wait\54\8
# Save data to  MP_Data_60FPS\wait\54\9
# Save data to  MP_Data_60FPS\wait\54\10
# Save data to  MP_Data_60FPS\wait\54\11
# Save data to  MP_Data_60FPS\wait\54\12
# Save data to  MP_Data_60FPS\wait\54\13
# Save data to  MP_Data_60FPS\wait\54\14
# Save data to  MP_Data_60FPS\wait\54\15
# Save data to  MP_Data_60FPS\wait\54\16
# Save data to  MP_Data_60FPS\wait\54\17
# Save data to  MP_Data_60FPS\wait\54\18
# Save data to  MP_Data_60FPS\wait\54\19
# Save data to  MP_Data_60FPS\wait\54\20
# Save data to  MP_Data_60FPS\wait\54\21
# Save data to  MP_Data_60FPS\wait\54\22
# Save data to  MP_Data_60FPS\wait\54\23
# Save data to  MP_Data_60FPS\wait\54\24
# Save data to  MP_Data_60FPS\wait\54\25
# Save data to  MP_Data_60FPS\wait\54\26
# Save data to  MP_Data_60FPS\wait\54\27
# Save data to  MP_Data_60FPS\wait\54\28
# Save data to  MP_Data_60FPS\wait\54\29
# Save data to  MP_Data_60FPS\wait\55\0
# Save data to  MP_Data_60FPS\wait\55\1
# Save data to  MP_Data_60FPS\wait\55\2
# Save data to  MP_Data_60FPS\wait\55\3
# Save data to  MP_Data_60FPS\wait\55\4
# Save data to  MP_Data_60FPS\wait\55\5
# Save data to  MP_Data_60FPS\wait\55\6
# Save data to  MP_Data_60FPS\wait\55\7
# Save data to  MP_Data_60FPS\wait\55\8
# Save data to  MP_Data_60FPS\wait\55\9
# Save data to  MP_Data_60FPS\wait\55\10
# Save data to  MP_Data_60FPS\wait\55\11
# Save data to  MP_Data_60FPS\wait\55\12
# Save data to  MP_Data_60FPS\wait\55\13
# Save data to  MP_Data_60FPS\wait\55\14
# Save data to  MP_Data_60FPS\wait\55\15
# Save data to  MP_Data_60FPS\wait\55\16
# Save data to  MP_Data_60FPS\wait\55\17
# Save data to  MP_Data_60FPS\wait\55\18
# Save data to  MP_Data_60FPS\wait\55\19
# Save data to  MP_Data_60FPS\wait\55\20
# Save data to  MP_Data_60FPS\wait\55\21
# Save data to  MP_Data_60FPS\wait\55\22
# Save data to  MP_Data_60FPS\wait\55\23
# Save data to  MP_Data_60FPS\wait\55\24
# Save data to  MP_Data_60FPS\wait\55\25
# Save data to  MP_Data_60FPS\wait\55\26
# Save data to  MP_Data_60FPS\wait\55\27
# Save data to  MP_Data_60FPS\wait\55\28
# Save data to  MP_Data_60FPS\wait\55\29
# Save data to  MP_Data_60FPS\wait\56\0
# Save data to  MP_Data_60FPS\wait\56\1
# Save data to  MP_Data_60FPS\wait\56\2
# Save data to  MP_Data_60FPS\wait\56\3
# Save data to  MP_Data_60FPS\wait\56\4
# Save data to  MP_Data_60FPS\wait\56\5
# Save data to  MP_Data_60FPS\wait\56\6
# Save data to  MP_Data_60FPS\wait\56\7
# Save data to  MP_Data_60FPS\wait\56\8
# Save data to  MP_Data_60FPS\wait\56\9
# Save data to  MP_Data_60FPS\wait\56\10
# Save data to  MP_Data_60FPS\wait\56\11
# Save data to  MP_Data_60FPS\wait\56\12
# Save data to  MP_Data_60FPS\wait\56\13
# Save data to  MP_Data_60FPS\wait\56\14
# Save data to  MP_Data_60FPS\wait\56\15
# Save data to  MP_Data_60FPS\wait\56\16
# Save data to  MP_Data_60FPS\wait\56\17
# Save data to  MP_Data_60FPS\wait\56\18
# Save data to  MP_Data_60FPS\wait\56\19
# Save data to  MP_Data_60FPS\wait\56\20
# Save data to  MP_Data_60FPS\wait\56\21
# Save data to  MP_Data_60FPS\wait\56\22
# Save data to  MP_Data_60FPS\wait\56\23
# Save data to  MP_Data_60FPS\wait\56\24
# Save data to  MP_Data_60FPS\wait\56\25
# Save data to  MP_Data_60FPS\wait\56\26
# Save data to  MP_Data_60FPS\wait\56\27
# Save data to  MP_Data_60FPS\wait\56\28
# Save data to  MP_Data_60FPS\wait\56\29
# Save data to  MP_Data_60FPS\wait\57\0
# Save data to  MP_Data_60FPS\wait\57\1
# Save data to  MP_Data_60FPS\wait\57\2
# Save data to  MP_Data_60FPS\wait\57\3
# Save data to  MP_Data_60FPS\wait\57\4
# Save data to  MP_Data_60FPS\wait\57\5
# Save data to  MP_Data_60FPS\wait\57\6
# Save data to  MP_Data_60FPS\wait\57\7
# Save data to  MP_Data_60FPS\wait\57\8
# Save data to  MP_Data_60FPS\wait\57\9
# Save data to  MP_Data_60FPS\wait\57\10
# Save data to  MP_Data_60FPS\wait\57\11
# Save data to  MP_Data_60FPS\wait\57\12
# Save data to  MP_Data_60FPS\wait\57\13
# Save data to  MP_Data_60FPS\wait\57\14
# Save data to  MP_Data_60FPS\wait\57\15
# Save data to  MP_Data_60FPS\wait\57\16
# Save data to  MP_Data_60FPS\wait\57\17
# Save data to  MP_Data_60FPS\wait\57\18
# Save data to  MP_Data_60FPS\wait\57\19
# Save data to  MP_Data_60FPS\wait\57\20
# Save data to  MP_Data_60FPS\wait\57\21
# Save data to  MP_Data_60FPS\wait\57\22
# Save data to  MP_Data_60FPS\wait\57\23
# Save data to  MP_Data_60FPS\wait\57\24
# Save data to  MP_Data_60FPS\wait\57\25
# Save data to  MP_Data_60FPS\wait\57\26
# Save data to  MP_Data_60FPS\wait\57\27
# Save data to  MP_Data_60FPS\wait\57\28
# Save data to  MP_Data_60FPS\wait\57\29
# Save data to  MP_Data_60FPS\wait\58\0
# Save data to  MP_Data_60FPS\wait\58\1
# Save data to  MP_Data_60FPS\wait\58\2
# Save data to  MP_Data_60FPS\wait\58\3
# Save data to  MP_Data_60FPS\wait\58\4
# Save data to  MP_Data_60FPS\wait\58\5
# Save data to  MP_Data_60FPS\wait\58\6
# Save data to  MP_Data_60FPS\wait\58\7
# Save data to  MP_Data_60FPS\wait\58\8
# Save data to  MP_Data_60FPS\wait\58\9
# Save data to  MP_Data_60FPS\wait\58\10
# Save data to  MP_Data_60FPS\wait\58\11
# Save data to  MP_Data_60FPS\wait\58\12
# Save data to  MP_Data_60FPS\wait\58\13
# Save data to  MP_Data_60FPS\wait\58\14
# Save data to  MP_Data_60FPS\wait\58\15
# Save data to  MP_Data_60FPS\wait\58\16
# Save data to  MP_Data_60FPS\wait\58\17
# Save data to  MP_Data_60FPS\wait\58\18
# Save data to  MP_Data_60FPS\wait\58\19
# Save data to  MP_Data_60FPS\wait\58\20
# Save data to  MP_Data_60FPS\wait\58\21
# Save data to  MP_Data_60FPS\wait\58\22
# Save data to  MP_Data_60FPS\wait\58\23
# Save data to  MP_Data_60FPS\wait\58\24
# Save data to  MP_Data_60FPS\wait\58\25
# Save data to  MP_Data_60FPS\wait\58\26
# Save data to  MP_Data_60FPS\wait\58\27
# Save data to  MP_Data_60FPS\wait\58\28
# Save data to  MP_Data_60FPS\wait\58\29
# Save data to  MP_Data_60FPS\wait\59\0
# Save data to  MP_Data_60FPS\wait\59\1
# Save data to  MP_Data_60FPS\wait\59\2
# Save data to  MP_Data_60FPS\wait\59\3
# Save data to  MP_Data_60FPS\wait\59\4
# Save data to  MP_Data_60FPS\wait\59\5
# Save data to  MP_Data_60FPS\wait\59\6
# Save data to  MP_Data_60FPS\wait\59\7
# Save data to  MP_Data_60FPS\wait\59\8
# Save data to  MP_Data_60FPS\wait\59\9
# Save data to  MP_Data_60FPS\wait\59\10
# Save data to  MP_Data_60FPS\wait\59\11
# Save data to  MP_Data_60FPS\wait\59\12
# Save data to  MP_Data_60FPS\wait\59\13
# Save data to  MP_Data_60FPS\wait\59\14
# Save data to  MP_Data_60FPS\wait\59\15
# Save data to  MP_Data_60FPS\wait\59\16
# Save data to  MP_Data_60FPS\wait\59\17
# Save data to  MP_Data_60FPS\wait\59\18
# Save data to  MP_Data_60FPS\wait\59\19
# Save data to  MP_Data_60FPS\wait\59\20
# Save data to  MP_Data_60FPS\wait\59\21
# Save data to  MP_Data_60FPS\wait\59\22
# Save data to  MP_Data_60FPS\wait\59\23
# Save data to  MP_Data_60FPS\wait\59\24
# Save data to  MP_Data_60FPS\wait\59\25
# Save data to  MP_Data_60FPS\wait\59\26
# Save data to  MP_Data_60FPS\wait\59\27
# Save data to  MP_Data_60FPS\wait\59\28
# Save data to  MP_Data_60FPS\wait\59\29

# %% [markdown]
# # CHECK GÓC TRƯỚC KHI QUAY THẬT

# %%
cap = cv2.VideoCapture(0)
#Set mediapipe
with mp_holistic.Holistic(min_detection_confidence = 0.5, min_tracking_confidence = 0.5) as holistic:
    while cap.isOpened():
        #Read feed
        ret, frame = cap.read()

        #Make detections
        image, results = mediapipe_detection(frame, holistic)
#         print(results)
        
        #Draw landmarks
#         draw_styled_landmarks(image, results)
        #Show to screen
        cv2.imshow('OpenCV Feed', image)
        
        #Break loop
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
draw_styled_landmarks(image, results)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
